# %% [markdown]
# ## Notebook 1

# %% [markdown]
# ## **Python Basics For Beginners: 'The Beginners Guide'**

# %% [markdown]
# **In This NoteBook We Will Learn About :**
# **1- Variables**
# **2- Data Types**
# **3- Arithmatic Operation**
# **4- Concatenate**
# **5- Input Values From User**

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## Creating Variables

# %%
x=5

# %%
# define variables with there values
print("x=",x)
# Out:
# x= 5

# %%
y = x 
print ("y = " , y)
# Out:
# y =  5

# %% [markdown]
# ## Data Types

# %%
a = 5 
b = 4.3
c = "String"
d = True 


print( a , type(a))
print(b , type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 5 <class 'int'>
# 4.3 <class 'float'>
# String <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ## Arithmatic Operations

# %%
Number1 = 10
Number2 = 2

print(Number1 + Number2)
print(Number1 - Number2)
print(Number1 * Number2)
print(Number1 ** Number2)
print(Number1 / Number2)
# Out:
# 12
# 8
# 20
# 100
# 5.0

# %% [markdown]
# ## Concatenation

# %%
Car = "BMW"
Model = " M4 CS"

print(Car + Model)
# Out:
# BMW M4 CS

# %%
# when we concatinat stirng with numerical number , we need to convert the integer number to sting first 

Mercedes = "AMG"
TypeOF = 1 

print(Mercedes + " " +str( 1))
# Out:
# AMG 1

# %%
#  \n to add a new line 

MyName = "AbdelRahman"
FatherName = "Alaa"

print (MyName + "\n "+ FatherName)
# Out:
# AbdelRahman
#  Alaa

# %% [markdown]
# ## How Can user Input Data

# %%
# I Will Ask User About His First Name And His Age .bash_history

FirstName = input(print("Pleae Enter Your First Name"))
Age = input(print("Pleas Enter Your Age"))
# Out:
# Pleae Enter Your First Name
# Pleas Enter Your Age

# %%
print("Hello Sir , Your First Name Is : " , FirstName)
print("And Your Age Is : " , Age)
# Out:
# Hello Sir , Your First Name Is :  AbdelRahman
# And Your Age Is :  24

# %% [markdown]
# ## Wait

# %%
# importing time library

import time

FirstName = input(print("Pleae Enter Your First Name"))

time.sleep(1)

print("Hello Sir , Your First Name Is : " , FirstName)
# Out:
# Pleae Enter Your First Name
# Hello Sir , Your First Name Is :  Abdo

# %%
# int() convert string into integer 

FirstNumber = int(input("Please Enter Your First Integer Number : "))
time.sleep(1.5)
SecondNumber = int(input("Please Enter Your Second Integer Number : "))

print("Your First Number Is : " , FirstNumber)
print("Your Second Number Is ; " , SecondNumber)
print("Your First Number + Second Number = " , FirstNumber + SecondNumber)
# Out:
# Your First Number Is :  5
# Your Second Number Is ;  6
# Your First Number + Second Number =  11

# %% [markdown]
# **This NoteBook Made By : Abdelrahman Alaa**

# %% [markdown]
#  **LinkedIn:**
#   **https://www.linkedin.com/in/abdelrahman1alaa**

# %% [markdown]
# **GitHub** : **https://github.com/abdelrahman1alaa**
